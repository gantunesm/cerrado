# %% [markdown]
# # View all cerrado colormaps

# %%
import matplotlib.pyplot as plt
import numpy as np
import cerrado

# %%
cerrado.view_all_colors()

# %%
#The color palletes are inspired in colors of the cerrado, for example: 

plt.figure()
cerrado.view_colormap('laelia')



def func3(x, y):
    return (1 - x / 2 + x**3 + y**2) * np.exp(-(x**2 + y**2))


dx, dy = 0.03, 0.03
x = np.arange(-3.0, 3.0, dx)
y = np.arange(-3.0, 3.0, dy)
X, Y = np.meshgrid(x, y) 
Z2 = func3(X, Y)

# cerrado.set_colormap('laelia')
plt.figure()
plt.imshow(Z2)
plt.colorbar()


from IPython.display import Image
Image(filename='/home/gabriela/Documents/Pesquisa/cerrado/docs/images/laelia.jpg', width="500")

# %%
plt.figure()
cerrado.view_colormap('chuveirinho')

Image(filename='/home/gabriela/Documents/Pesquisa/cerrado/docs/images/chuveirinho.png', width="500")

# %%
plt.figure()
cerrado.view_colormap('santa_barbara')

Image(filename='/home/gabriela/Documents/Pesquisa/cerrado/docs/images/santa_barbara.jpeg', width="300")

# %% [markdown]
# # Default color cycles

# %% [markdown]
# The default of cerrado is 'chuveirinho'

# %%
a = np.linspace(0, 2*np.pi, 100)

plt.plot(a, np.sin(a))

plt.plot(a, np.cos(a))
plt.plot(a, np.cos(a+0.5))
plt.plot(a, np.cos(a+1))
plt.plot(a, np.cos(a+1.5))
plt.plot(a, np.cos(a+2))

plt.title('Title')
plt.xlabel('axis-x')
plt.ylabel('axis-y')
# Out:
# Text(0, 0.5, 'axis-y')

# %% [markdown]
# ### Picking another color cycle

# %%
cerrado.set_color_cycle('cariocas')

# %%
a = np.linspace(0, 2*np.pi, 100)

plt.plot(a, np.sin(a))

plt.plot(a, np.cos(a))
plt.plot(a, np.cos(a+0.5))
plt.plot(a, np.cos(a+1))
plt.plot(a, np.cos(a+1.5))
plt.plot(a, np.cos(a+2))

plt.title('Cariocas colors')
plt.xlabel('xxx')
plt.ylabel('yyy')
# Out:
# Text(0, 0.5, 'yyy')

# %%
cerrado.set_color_cycle('caliandra')

plt.plot(a, np.sin(a))
plt.plot(a, np.cos(a))
plt.plot(a, np.cos(a+0.5))
plt.plot(a, np.cos(a+1))
plt.plot(a, np.cos(a+1.5))
plt.plot(a, np.cos(a+2))

plt.title('Caliandra colors')
plt.xlabel('xxx')
plt.ylabel('yyy')
# Out:
# Text(0, 0.5, 'yyy')

# %%
cerrado.set_color_cycle('caliandra_II')

plt.plot(a, np.sin(a))

plt.plot(a, np.cos(a))
plt.plot(a, np.cos(a+0.5))
plt.plot(a, np.cos(a+1))
plt.plot(a, np.cos(a+1.5))
plt.plot(a, np.cos(a+2))

plt.title('Caliandra II colors')
plt.xlabel('xxx')
plt.ylabel('yyy')
# Out:
# Text(0, 0.5, 'yyy')

# %% [markdown]
# # Colormap

# %%
cerrado.set_colormap('chuveirinho_bright')
Z = np.random.random((50,50))   # Test data
plt.imshow(Z)

# %% [markdown]
# ### Picking another colormap

# %%
cerrado.set_colormap('cer2')
plt.imshow(Z)

# %%
def func3(x, y):
    return (1 - x / 2 + x**3 + y**2) * np.exp(-(x**2 + y**2))


# make these smaller to increase the resolution
dx, dy = 0.03, 0.03

x = np.arange(-3.0, 3.0, dx)
y = np.arange(-3.0, 3.0, dy)
X, Y = np.meshgrid(x, y) 
Z2 = func3(X, Y)

# %%
cerrado.set_colormap('santa_barbara')
plt.imshow(Z2)
plt.colorbar()

# %%
cerrado.set_colormap('cer2')
plt.imshow(Z2)
plt.colorbar()

# %%
cerrado.set_colormap('laelia')
plt.imshow(Z2)
plt.colorbar()
